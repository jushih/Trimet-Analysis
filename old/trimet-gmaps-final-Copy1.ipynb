# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key="AIzaSyCAqLcxb3Yi12QBVdel1binUdydxFAkNyw")

import pandas as pd

events = pd.read_csv('events_month.csv')
trips = pd.read_csv('trips_month.csv')

#convert utc timestamp to local time
events['timestamp'] = pd.to_datetime(events['timestamp'])
events['pst'] = events['timestamp'].dt.tz_localize('UTC').dt.tz_convert('US/Pacific')

#add hour column
events['hour'] = events['pst'].dt.strftime('%-H') 
events['hour'] = events['hour'].astype(int)

events[events.delay > 0 ] = 0 #set early arrivals to 0
delays = events.loc[events['delay'] < -60 ]
delays['abs'] = delays.delay*-1 #transform delays to positive values, gmaps can't accept negatives

# %%
#parse delays by hour
delays_0 = delays.loc[delays['hour'] ==0]
delays_1 = delays.loc[delays['hour'] ==1]
delays_2 = delays.loc[delays['hour'] ==2]
delays_3 = delays.loc[delays['hour'] ==3]
delays_4 = delays.loc[delays['hour'] ==4]
delays_5 = delays.loc[delays['hour'] ==5]
delays_6 = delays.loc[delays['hour'] ==6]
delays_7 = delays.loc[delays['hour'] ==7]
delays_8 = delays.loc[delays['hour'] ==8]
delays_9 = delays.loc[delays['hour'] ==9]
delays_10 = delays.loc[delays['hour'] ==10]
delays_11 = delays.loc[delays['hour'] ==11]
delays_12 = delays.loc[delays['hour'] ==12]
delays_13 = delays.loc[delays['hour'] ==13]
delays_14 = delays.loc[delays['hour'] ==14]
delays_15 = delays.loc[delays['hour'] ==15]
delays_16 = delays.loc[delays['hour'] ==16]
delays_17 = delays.loc[delays['hour'] ==17]
delays_18 = delays.loc[delays['hour'] ==18]
delays_19 = delays.loc[delays['hour'] ==19]
delays_20 = delays.loc[delays['hour'] ==20]
delays_21 = delays.loc[delays['hour'] ==21]
delays_22 = delays.loc[delays['hour'] ==22]
delays_23 = delays.loc[delays['hour'] ==23]

# %%
portland_coord = (45.51,-122.65)
figure_layout = {
    'height': '500px'
}

fig = gmaps.figure(center=portland_coord, zoom_level=11, layout=figure_layout)

heatmap_layer = gmaps.heatmap_layer(
    delays_17[['vehicle_location_latitude', 'vehicle_location_longitude']], weights=delays_17['abs'],
    max_intensity=50000, point_radius=8.0
)


fig.add_layer(heatmap_layer)
fig

# %%
#events = pd.read_csv('events_month.csv')
#trips = pd.read_csv('trips_month.csv')

#join events to trips
#df_events = pd.merge(events,trips, how='left', left_on=['tripID','vehicle_id'], right_on = ['tripID','vehicle_id'])


delays = events.loc[events['delay'] < -60 ]
delays['abs'] = delays.delay*-1 #transform delays to positive values

delays_4 = delays.loc[delays['hour'] == 4]
delays_8 = delays.loc[delays['hour'] == 8]
delays_16 = delays.loc[delays['hour'] == 16]


on_time_0 = events.loc[(events['delay'] >= -60) & (events['hour'] ==0) ]
on_time_2 = events.loc[(events['delay'] >= -60) & (events['hour'] ==2) ]
on_time_4 = events.loc[(events['delay'] >= -60) & (events['hour'] ==4) ]
on_time_6 = events.loc[(events['delay'] >= -60) & (events['hour'] ==6) ]
on_time_8 = events.loc[(events['delay'] >= -60) & (events['hour'] ==8) ]
on_time_10 = events.loc[(events['delay'] >= -60) & (events['hour'] ==10) ]
on_time_12 = events.loc[(events['delay'] >= -60) & (events['hour'] ==12) ]
on_time_14 = events.loc[(events['delay'] >= -60) & (events['hour'] ==14) ]
on_time_16 = events.loc[(events['delay'] >= -60) & (events['hour'] ==16) ]
on_time_18 = events.loc[(events['delay'] >= -60) & (events['hour'] ==18) ]
on_time_20 = events.loc[(events['delay'] >= -60) & (events['hour'] ==20) ]
on_time_22 = events.loc[(events['delay'] >= -60) & (events['hour'] ==22) ]
# Out:
# /Users/julieshih/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
on_time_8
# Out:
#         bearing  delay           timestamp  lastLocID  lastStopSeq  nextLocID  \
# 186004      270      9 2017-01-14 16:17:11       9842           44       9844
# 135205       19     53 2017-01-05 16:05:56       9759           19       9758
# 459947      121     26 2017-01-21 16:28:56       8356           45       8357
# 406966      144      3 2017-01-16 16:42:37      10579            1      10577
# 369663       90     -9 2017-01-21 16:12:51       8340           14       8341
# 386204      270    -33 2017-01-19 16:10:21       8375           11       8376
# 353947       91    -15 2017-01-18 16:00:23       8342           16       8343
# 399363      291    -50 2017-01-21 16:40:01       8383           19       8384
# 420042       89    -46 2017-01-24 16:06:26       8343           31       8344
# 258544       20    -15 2017-01-03 16:26:07       7787            6       9299
# 399375      296    -56 2017-01-21 16:15:10       8371            7       8372
# ...

# %%
portland_coord = (45.51,-122.65)
figure_layout = {
    'height': '500px',
    'padding': '1px'
}
fig = gmaps.figure(center=portland_coord, zoom_level=11, layout=figure_layout)




#delays_layer = gmaps.symbol_layer(
#    delays_16[['vehicle_location_latitude', 'vehicle_location_longitude']],
#    fill_opacity=0.2,
#    fill_color ='rgba(200, 0, 0, 0.4)',
#    stroke_color='rgba(200, 0, 0, 0.4)', scale=2
#)

#on_time_layer = gmaps.symbol_layer(
#    on_time_16[['vehicle_location_latitude', 'vehicle_location_longitude']], 
#    fill_opacity=0.2,
#    fill_color = 'rgba(0, 221, 0, 0.4)',
#    stroke_color='rgba(0, 221, 0, 0.4)', scale=2
#)

# %%
delays_0 = delays.loc[delays['hour'] ==0]
delays_1 = delays.loc[delays['hour'] ==1]
delays_2 = delays.loc[delays['hour'] ==2]
delays_3 = delays.loc[delays['hour'] ==3]
delays_4 = delays.loc[delays['hour'] ==4]
delays_5 = delays.loc[delays['hour'] ==5]
delays_6 = delays.loc[delays['hour'] ==6]
delays_7 = delays.loc[delays['hour'] ==7]
delays_8 = delays.loc[delays['hour'] ==8]
delays_9 = delays.loc[delays['hour'] ==9]
delays_10 = delays.loc[delays['hour'] ==10]
delays_11 = delays.loc[delays['hour'] ==11]
delays_12 = delays.loc[delays['hour'] ==12]
delays_13 = delays.loc[delays['hour'] ==13]
delays_14 = delays.loc[delays['hour'] ==14]
delays_15 = delays.loc[delays['hour'] ==15]
delays_16 = delays.loc[delays['hour'] ==16]
delays_17 = delays.loc[delays['hour'] ==17]
delays_18 = delays.loc[delays['hour'] ==18]
delays_19 = delays.loc[delays['hour'] ==19]
delays_20 = delays.loc[delays['hour'] ==20]
delays_21 = delays.loc[delays['hour'] ==21]
delays_22 = delays.loc[delays['hour'] ==22]
delays_23 = delays.loc[delays['hour'] ==23]

# %%
portland_coord = (45.51,-122.65)
figure_layout = {
    'height': '500px'
}

fig = gmaps.figure(center=portland_coord, zoom_level=11, layout=figure_layout)

heatmap_layer = gmaps.heatmap_layer(
    delays_2[['vehicle_location_latitude', 'vehicle_location_longitude']], weights=delays_2['abs'],
    max_intensity=50000, point_radius=8.0
)


fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='500px'))

# %%
portland_coord = (45.51,-122.65)
figure_layout = {
    'height': '500px'
}

fig = gmaps.figure(center=portland_coord, zoom_level=11, layout=figure_layout)

heatmap_layer = gmaps.heatmap_layer(
    delays_17[['vehicle_location_latitude', 'vehicle_location_longitude']], weights=delays_17['abs'],
    max_intensity=50000, point_radius=8.0
)


fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='500px'))

# %%
portland_coord = (45.51,-122.65)
figure_layout = {
    'height': '500px'
}

fig = gmaps.figure(center=portland_coord, zoom_level=11, layout=figure_layout)

heatmap_layer = gmaps.heatmap_layer(
    delays_22[['vehicle_location_latitude', 'vehicle_location_longitude']], weights=delays_22['abs'],
    max_intensity=50000, point_radius=8.0
)


fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='500px'))

# %%
#https://github.com/pbugnion/gmaps/blob/master/docs/source/install.rst
#http://jupyter-gmaps.readthedocs.io/en/latest/tutorial.html#base-maps
